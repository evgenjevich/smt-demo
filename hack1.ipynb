# %% [markdown]
# # Using Sumatra with Pandas in IPython
#
# This notebook demonstrates how to use
# [Sumatra](http://neuralensemble.org/sumatra/) to capture simulation
# input data and meta data and then
# export these records into a Pandas data frame.  Sumatra has a stand
# alone web interface built with Django which allows users to view the
# data. Data can also be imported into Python, but requires a lot of
# code to manipulate and display in useful custom formats. Pandas seems
# like the ideal solution for manipulating Sumatra's data. In particular
# the ability to easily and quickly combine input data, meta data, and
# output data into custom data frames is really powerful for
# data analysis, reproduciblity and sharing.
#
# The first step in using Sumatra is to setup a simulation. Here the
# simulation just runs a diffusion problem using FiPy and outputs the
# time taken for a time step. The goal of the work is to test FiPy's parallel
# speed up based on different input parameters.

# %% [markdown]
# # Setup the Simulations

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Sumatra requires a file with the parameters specified.

# %%
#creates a params.json dictionary {nx,ny,steps}
import json
import hackathon_params as hp

hp.hackParams(10,2)

# %% [markdown]
# The script file for running the simulation is `hack1.py`. It reads the JSON file, runs the simulation and the stores the run times in `data.txt`.

# %%
# %%writefile hack1.py

import fipy as fp
import numpy as np
import json
import os
import hackathon_params as hp
import sys

jsonfile = sys.argv[1]

if jsonfile:
    with open(jsonfile, 'rb') as ff:
        params = json.load(ff)
else:
    params = dict()

#print type(params)
print 'my params:', params



N = params.get('N',20)
total_steps = params.get('steps',2)
sumatra_label = params.get('sumatra_label', '')

mesh = fp.PeriodicGrid2D(nx=N, ny=N, dx=0.5, dy=0.5)    # changed 400 to 40 for nx and ny to test a faster run

c_alpha = 0.05
c_beta = 0.95
A = 2.0
kappa = 2.0
c_m = (c_alpha + c_beta) / 2.
B = A / (c_alpha - c_m)**2
D = D_alpha = D_beta = 2. / (c_beta - c_alpha)
c_0 = 0.45
q = np.sqrt((2., 3.))
epsilon = 0.01

c_var = fp.CellVariable(mesh=mesh, name=r"$c$", hasOld=True)

r = np.array((mesh.x, mesh.y))
c_var[:] = c_0 + epsilon * np.cos((q[:, None] * r).sum(0))

f_0_var = -A + 3*B*(c_var - c_m)**2 + 3*c_alpha*(c_var - c_alpha)**2 + 3*c_beta*(c_var - c_beta)**2

eqn = fp.TransientTerm(coeff=1.) == fp.DiffusionTerm(D * f_0_var) - fp.DiffusionTerm((D, kappa))

elapsed = 0.0
steps = 0
dt = 0.01
total_sweeps = 2
tolerance = 1e-1
#total_steps = 2       #from 1000 to 100

c_var[:] = c_0 + epsilon * np.cos((q[:, None] * r).sum(0))

c_var.updateOld()

from fipy.solvers.pysparse import LinearLUSolver as Solver

solver = Solver()

# viewer = fp.Viewer(c_var)
while steps < total_steps:
    res0 = eqn.sweep(c_var, dt=dt, solver=solver)

    for sweeps in range(total_sweeps):
        res = eqn.sweep(c_var, dt=dt, solver=solver)

        print ' '
        print 'steps',steps
        print 'res',res
        print 'sweeps',sweeps
        print 'dt',dt


    if res < res0 * tolerance:
        steps += 1
        elapsed += dt
        dt *= 1.1
#         if steps % 1 == 0:
#              viewer.plot('image{0}.png'.format(steps))
        c_var.updateOld()
    else:
        dt *= 0.8
        c_var[:] = c_var.old
        
        
    #create a filepath and txt file to save the output c_var values
    filepath = os.path.join('Data', sumatra_label)
    filename = 'c_var_outputs.txt'
    np.savetxt(os.path.join(filepath, filename), np.array(c_var))
# Out:
# Overwriting hack1.py

# %% [markdown]
# Without using Sumatra and in serial this is run with

# %%
#to install gmsh run "conda install --channel guyer numpy==1.9 pysparse pip gmsh"
#to install PyTrilinos run "conda install --channel guyer numpy==1.9 pysparse openmpi trilinos mpi4py"
#trilinos is mainly used for linear solvers, it also includes PDE solvers but they are low level, FiPy is a better PDE solvers

#but actually you should use pysparse instead of trilinos
# !python hack1.py params.json
# Out:
# my params: {u'steps': 2, u'N': 10}
#
# steps 0
# res 0.00194075927043
# sweeps 0
# dt 0.01
#
# steps 0
# res 6.52810688478e-07
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.000544573625072
# sweeps 0
# dt 0.011
#
# steps 1
# res 1.63931995157e-07
# sweeps 1
# dt 0.011

# %% [markdown]
# and the output data file is

# %% [markdown]
# # Create a Git Repository

# %% [markdown]
# In this demo, I'm assuming that the working directory is a Git repository set up with
#
#     $ git init
# $ git add hack1.py
#     $ git ci -m "Add timing script."
#
# Sumatra requires that the script is sitting in the a working copy of a repository.

# %%
# !git log -1
# Out:
# commit cf2e93ee897f9a8ac5091021bb5e6b431ad0f831
# Author: Andrey Moskalenko <andrey.moskalenko@nist.gov>
# Date:   Mon Jun 6 11:15:28 2016 -0400
#
#     added hack1 file to run with the python notebook

# %% [markdown]
# # Configure Sumatra

# %% [markdown]
# Once the repository is setup, the Sumatra repository can be configured. Here we are using the `distributed` launch mode as we want Sumatra to launch and
# record parallel jobs.

# %%
# %%bash
#
# rm -rf .smt
# smt init hack1-demo
# smt configure --executable=python --main=hack1.py
# smt configure --launch_mode=serial
# smt configure -g uuid
# smt configure -c store-diff
# smt configure --addlabel=parameters
# Out:
# Sumatra project successfully set up
# Multiple versions found, using /users/aem1/miniconda2/bin/python. If you wish to use a different version, please specify it explicitly
# Multiple versions found, using /users/aem1/miniconda2/bin/python. If you wish to use a different version, please specify it explicitly

# %% [markdown]
# Sumatra requires that  a `Data/` directory exists in the working copy.

# %%
# !mkdir Data
# Out:
# mkdir: cannot create directory ‘Data’: File exists

# %% [markdown]
# If we were not using Sumatra, we would launch the job with
#
#     $ mpirun -n 2 python hack1.py params.json
#
# The equivalent command using Sumatra is
#
#     $ smt run -n 2 params.json

# %% [markdown]
# # Run Simulations
#
# In the following cell we just run a batch of simulations with varying parameters.

# %%
import itertools

N=(10, 15, 20, 30, 40)
steps=(2, 10, 20)
tag='hack1'

for N, steps in itertools.product(N, steps):
    hp.hackParams(N,steps)
    # !smt run params.json --tag=$tag
# Out:
# my params: {u'N': 10, u'steps': 2, u'sumatra_label': u'f26f36cf9d43'}
#
# steps 0
# res 0.00194075927043
# sweeps 0
# dt 0.01
#
# steps 0
# res 6.52810688478e-07
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.000544573625072
# sweeps 0
# dt 0.011
#
# steps 1
# res 1.63931995157e-07
# sweeps 1
# dt 0.011
# Record label for this run: 'f26f36cf9d43'
# Data keys are [c_var_outputs.txt(5773e6905d793fef15e54c55441c9e6112eb284c [2016-06-06 15:42:57])]
# my params: {u'N': 10, u'steps': 10, u'sumatra_label': u'052b46043c22'}
#
# steps 0
# res 0.00194075927043
# sweeps 0
# dt 0.01
#
# steps 0
# res 6.52810688478e-07
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.000544573625072
# sweeps 0
# dt 0.011
#
# steps 1
# res 1.63931995157e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000236511819802
# sweeps 0
# dt 0.0121
#
# steps 2
# res 6.71391241948e-08
# sweeps 1
# dt 0.0121
#
# steps 3
# res 0.000126874199398
# sweeps 0
# dt 0.01331
#
# steps 3
# res 3.13778524112e-08
# sweeps 1
# dt 0.01331
#
# steps 4
# res 6.93808536792e-05
# sweeps 0
# dt 0.014641
#
# steps 4
# res 1.45718634259e-08
# sweeps 1
# dt 0.014641
#
# steps 5
# res 3.76543150732e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 6.77264414632e-09
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 2.06447825705e-05
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 3.24420745177e-09
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 1.1660072542e-05
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 1.65117195957e-09
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 6.90184524883e-06
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 9.14714634132e-10
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 4.36661623796e-06
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 5.54535327597e-10
# sweeps 1
# dt 0.02357947691
# Record label for this run: '052b46043c22'
# Data keys are [c_var_outputs.txt(0939ea1208b6ad1ece471a8ccce83e0168bfd3cc [2016-06-06 15:43:57])]
# my params: {u'N': 10, u'steps': 20, u'sumatra_label': u'd8378b287345'}
#
# steps 0
# res 0.00194075927043
# sweeps 0
# dt 0.01
#
# steps 0
# res 6.52810688478e-07
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.000544573625072
# sweeps 0
# dt 0.011
#
# steps 1
# res 1.63931995157e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000236511819802
# sweeps 0
# dt 0.0121
#
# steps 2
# res 6.71391241948e-08
# sweeps 1
# dt 0.0121
#
# steps 3
# res 0.000126874199398
# sweeps 0
# dt 0.01331
#
# steps 3
# res 3.13778524112e-08
# sweeps 1
# dt 0.01331
#
# steps 4
# res 6.93808536792e-05
# sweeps 0
# dt 0.014641
#
# steps 4
# res 1.45718634259e-08
# sweeps 1
# dt 0.014641
#
# steps 5
# res 3.76543150732e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 6.77264414632e-09
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 2.06447825705e-05
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 3.24420745177e-09
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 1.1660072542e-05
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 1.65117195957e-09
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 6.90184524883e-06
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 9.14714634132e-10
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 4.36661623796e-06
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 5.54535327597e-10
# sweeps 1
# dt 0.02357947691
#
# steps 10
# res 2.98154054759e-06
# sweeps 0
# dt 0.025937424601
#
# steps 10
# res 3.58407092481e-10
# sweeps 1
# dt 0.025937424601
#
# steps 11
# res 2.15471494868e-06
# sweeps 0
# dt 0.0285311670611
#
# steps 11
# res 2.36295271475e-10
# sweeps 1
# dt 0.0285311670611
#
# steps 12
# res 1.58892891707e-06
# sweeps 0
# dt 0.0313842837672
#
# steps 12
# res 1.53253870304e-10
# sweeps 1
# dt 0.0313842837672
#
# steps 13
# res 1.16060194489e-06
# sweeps 0
# dt 0.0345227121439
#
# steps 13
# res 9.55802686899e-11
# sweeps 1
# dt 0.0345227121439
#
# steps 14
# res 8.25621207831e-07
# sweeps 0
# dt 0.0379749833583
#
# steps 14
# res 5.66777188968e-11
# sweeps 1
# dt 0.0379749833583
#
# steps 15
# res 5.66994969962e-07
# sweeps 0
# dt 0.0417724816942
#
# steps 15
# res 3.17736938398e-11
# sweeps 1
# dt 0.0417724816942
#
# steps 16
# res 3.73963502415e-07
# sweeps 0
# dt 0.0459497298636
#
# steps 16
# res 1.67142964213e-11
# sweeps 1
# dt 0.0459497298636
#
# steps 17
# res 2.35961070714e-07
# sweeps 0
# dt 0.0505447028499
#
# steps 17
# res 8.23312573072e-12
# sweeps 1
# dt 0.0505447028499
#
# steps 18
# res 1.41927988289e-07
# sweeps 0
# dt 0.0555991731349
#
# steps 18
# res 3.72694521384e-12
# sweeps 1
# dt 0.0555991731349
#
# steps 19
# res 8.10896202664e-08
# sweeps 0
# dt 0.0611590904484
#
# steps 19
# res 1.57967617913e-12
# sweeps 1
# dt 0.0611590904484
# Record label for this run: 'd8378b287345'
# Data keys are [c_var_outputs.txt(87dcdd506e5b62b1ae87adff38c42efdd3641b95 [2016-06-06 15:44:32])]
# my params: {u'N': 15, u'steps': 2, u'sumatra_label': u'36a112015922'}
#
# steps 0
# res 0.00315773205683
# sweeps 0
# dt 0.01
#
# steps 0
# res 7.90821062208e-07
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.000853449771765
# sweeps 0
# dt 0.011
#
# steps 1
# res 1.28731538944e-07
# sweeps 1
# dt 0.011
# Record label for this run: '36a112015922'
# Data keys are [c_var_outputs.txt(e8117ef32855265eae8a0d24efe5e47f1d9715aa [2016-06-06 15:45:09])]
# my params: {u'N': 15, u'steps': 10, u'sumatra_label': u'c9ec3e4caf03'}
#
# steps 0
# res 0.00315773205683
# sweeps 0
# dt 0.01
#
# steps 0
# res 7.90821062208e-07
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.000853449771765
# sweeps 0
# dt 0.011
#
# steps 1
# res 1.28731538944e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000242159993574
# sweeps 0
# dt 0.0121
#
# steps 2
# res 2.40587141573e-08
# sweeps 1
# dt 0.0121
#
# steps 3
# res 7.39181489006e-05
# sweeps 0
# dt 0.01331
#
# steps 3
# res 5.62576739613e-09
# sweeps 1
# dt 0.01331
#
# steps 4
# res 2.68671443869e-05
# sweeps 0
# dt 0.014641
#
# steps 4
# res 1.72294692415e-09
# sweeps 1
# dt 0.014641
#
# steps 5
# res 1.15194172041e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 6.01182724699e-10
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 5.19503568477e-06
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 2.21205051167e-10
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 2.35464310202e-06
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 8.71254968305e-11
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 1.09902674416e-06
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 3.77651181878e-11
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 5.50536938268e-07
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 1.84296460929e-11
# sweeps 1
# dt 0.02357947691
# Record label for this run: 'c9ec3e4caf03'
# Data keys are [c_var_outputs.txt(1b08416a0485aba07c6a6b83857af91a48c01d0d [2016-06-06 15:45:51])]
# my params: {u'N': 15, u'steps': 20, u'sumatra_label': u'e6a47fb8223f'}
#
# steps 0
# res 0.00315773205683
# sweeps 0
# dt 0.01
#
# steps 0
# res 7.90821062208e-07
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.000853449771765
# sweeps 0
# dt 0.011
#
# steps 1
# res 1.28731538944e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000242159993574
# sweeps 0
# dt 0.0121
#
# steps 2
# res 2.40587141573e-08
# sweeps 1
# dt 0.0121
#
# steps 3
# res 7.39181489006e-05
# sweeps 0
# dt 0.01331
#
# steps 3
# res 5.62576739613e-09
# sweeps 1
# dt 0.01331
#
# steps 4
# res 2.68671443869e-05
# sweeps 0
# dt 0.014641
#
# steps 4
# res 1.72294692415e-09
# sweeps 1
# dt 0.014641
#
# steps 5
# res 1.15194172041e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 6.01182724699e-10
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 5.19503568477e-06
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 2.21205051167e-10
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 2.35464310202e-06
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 8.71254968305e-11
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 1.09902674416e-06
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 3.77651181878e-11
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 5.50536938268e-07
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 1.84296460929e-11
# sweeps 1
# dt 0.02357947691
#
# steps 10
# res 3.00729797907e-07
# sweeps 0
# dt 0.025937424601
#
# steps 10
# res 1.01515504028e-11
# sweeps 1
# dt 0.025937424601
#
# steps 11
# res 1.78307101383e-07
# sweeps 0
# dt 0.0285311670611
#
# steps 11
# res 6.31896646498e-12
# sweeps 1
# dt 0.0285311670611
#
# steps 12
# res 1.15393373065e-07
# sweeps 0
# dt 0.0313842837672
#
# steps 12
# res 4.35446748858e-12
# sweeps 1
# dt 0.0313842837672
#
# steps 13
# res 8.22729241724e-08
# sweeps 0
# dt 0.0345227121439
#
# steps 13
# res 3.27123452086e-12
# sweeps 1
# dt 0.0345227121439
#
# steps 14
# res 6.37076339924e-08
# sweeps 0
# dt 0.0379749833583
#
# steps 14
# res 2.55001213791e-12
# sweeps 1
# dt 0.0379749833583
#
# steps 15
# res 5.18558740521e-08
# sweeps 0
# dt 0.0417724816942
#
# steps 15
# res 2.13481484849e-12
# sweeps 1
# dt 0.0417724816942
#
# steps 16
# res 4.31553723382e-08
# sweeps 0
# dt 0.0459497298636
#
# steps 16
# res 1.74841221254e-12
# sweeps 1
# dt 0.0459497298636
#
# steps 17
# res 3.61570715373e-08
# sweeps 0
# dt 0.0505447028499
#
# steps 17
# res 1.47071223539e-12
# sweeps 1
# dt 0.0505447028499
#
# steps 18
# res 3.0290570382e-08
# sweeps 0
# dt 0.0555991731349
#
# steps 18
# res 1.27326649631e-12
# sweeps 1
# dt 0.0555991731349
#
# steps 19
# res 2.53305798846e-08
# sweeps 0
# dt 0.0611590904484
#
# steps 19
# res 1.0786915252e-12
# sweeps 1
# dt 0.0611590904484
# Record label for this run: 'e6a47fb8223f'
# Data keys are [c_var_outputs.txt(02dfa17183adefb160a353704c0c6a7948761760 [2016-06-06 15:46:30])]
# my params: {u'N': 20, u'steps': 2, u'sumatra_label': u'98812abd136d'}
#
# steps 0
# res 0.0042960339522
# sweeps 0
# dt 0.01
#
# steps 0
# res 1.08486485896e-06
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.00113404736018
# sweeps 0
# dt 0.011
#
# steps 1
# res 2.03089424151e-07
# sweeps 1
# dt 0.011
# Record label for this run: '98812abd136d'
# Data keys are [c_var_outputs.txt(50aff887650d39871f1ad8fed7e3a04567b5d709 [2016-06-06 15:47:02])]
# my params: {u'N': 20, u'steps': 10, u'sumatra_label': u'e8ad6a451d27'}
#
# steps 0
# res 0.0042960339522
# sweeps 0
# dt 0.01
#
# steps 0
# res 1.08486485896e-06
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.00113404736018
# sweeps 0
# dt 0.011
#
# steps 1
# res 2.03089424151e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000350096166434
# sweeps 0
# dt 0.0121
#
# steps 2
# res 4.79732102702e-08
# sweeps 1
# dt 0.0121
#
# steps 3
# res 0.000118388865991
# sweeps 0
# dt 0.01331
#
# steps 3
# res 1.42802971663e-08
# sweeps 1
# dt 0.01331
#
# steps 4
# res 4.54853493484e-05
# sweeps 0
# dt 0.014641
#
# steps 4
# res 6.11302324143e-09
# sweeps 1
# dt 0.014641
#
# steps 5
# res 2.23525217982e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 3.72804600933e-09
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 1.40043254085e-05
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 2.5614102386e-09
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 9.71170927691e-06
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 1.77084993709e-09
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 6.90581210808e-06
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 1.21067644319e-09
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 4.94177741765e-06
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 8.21098820479e-10
# sweeps 1
# dt 0.02357947691
# Record label for this run: 'e8ad6a451d27'
# Data keys are [c_var_outputs.txt(d1c15ddb0bcb26a5850ed0ebeb63a239552235c7 [2016-06-06 15:47:35])]
# my params: {u'N': 20, u'steps': 20, u'sumatra_label': u'779d02f0c3e8'}
#
# steps 0
# res 0.0042960339522
# sweeps 0
# dt 0.01
#
# steps 0
# res 1.08486485896e-06
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.00113404736018
# sweeps 0
# dt 0.011
#
# steps 1
# res 2.03089424151e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000350096166434
# sweeps 0
# dt 0.0121
#
# steps 2
# res 4.79732102702e-08
# sweeps 1
# dt 0.0121
#
# steps 3
# res 0.000118388865991
# sweeps 0
# dt 0.01331
#
# steps 3
# res 1.42802971663e-08
# sweeps 1
# dt 0.01331
#
# steps 4
# res 4.54853493484e-05
# sweeps 0
# dt 0.014641
#
# steps 4
# res 6.11302324143e-09
# sweeps 1
# dt 0.014641
#
# steps 5
# res 2.23525217982e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 3.72804600933e-09
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 1.40043254085e-05
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 2.5614102386e-09
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 9.71170927691e-06
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 1.77084993709e-09
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 6.90581210808e-06
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 1.21067644319e-09
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 4.94177741765e-06
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 8.21098820479e-10
# sweeps 1
# dt 0.02357947691
#
# steps 10
# res 3.54570417792e-06
# sweeps 0
# dt 0.025937424601
#
# steps 10
# res 5.55392563982e-10
# sweeps 1
# dt 0.025937424601
#
# steps 11
# res 2.54806616168e-06
# sweeps 0
# dt 0.0285311670611
#
# steps 11
# res 3.76165708602e-10
# sweeps 1
# dt 0.0285311670611
#
# steps 12
# res 1.83421206844e-06
# sweeps 0
# dt 0.0313842837672
#
# steps 12
# res 2.5610252881e-10
# sweeps 1
# dt 0.0313842837672
#
# steps 13
# res 1.32440744211e-06
# sweeps 0
# dt 0.0345227121439
#
# steps 13
# res 1.76197791817e-10
# sweeps 1
# dt 0.0345227121439
#
# steps 14
# res 9.61383372552e-07
# sweeps 0
# dt 0.0379749833583
#
# steps 14
# res 1.23015665302e-10
# sweeps 1
# dt 0.0379749833583
#
# steps 15
# res 7.03010518977e-07
# sweeps 0
# dt 0.0417724816942
#
# steps 15
# res 8.75723879074e-11
# sweeps 1
# dt 0.0417724816942
#
# steps 16
# res 5.18316646098e-07
# sweeps 0
# dt 0.0459497298636
#
# steps 16
# res 6.38916714403e-11
# sweeps 1
# dt 0.0459497298636
#
# steps 17
# res 3.85140127817e-07
# sweeps 0
# dt 0.0505447028499
#
# steps 17
# res 4.78889005246e-11
# sweeps 1
# dt 0.0505447028499
#
# steps 18
# res 2.88300974664e-07
# sweeps 0
# dt 0.0555991731349
#
# steps 18
# res 3.70809344312e-11
# sweeps 1
# dt 0.0555991731349
#
# steps 19
# res 2.17866939113e-07
# sweeps 0
# dt 0.0611590904484
#
# steps 19
# res 2.97894419568e-11
# sweeps 1
# dt 0.0611590904484
# Record label for this run: '779d02f0c3e8'
# Data keys are [c_var_outputs.txt(1bcccfc8dee907e760f5b23bf14270ece9e2791b [2016-06-06 15:48:08])]
# my params: {u'N': 30, u'steps': 2, u'sumatra_label': u'ef3a66163116'}
#
# steps 0
# res 0.00642931458806
# sweeps 0
# dt 0.01
#
# steps 0
# res 1.72825654227e-06
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.00188183642282
# sweeps 0
# dt 0.011
#
# steps 1
# res 3.34202721889e-07
# sweeps 1
# dt 0.011
# Record label for this run: 'ef3a66163116'
# Data keys are [c_var_outputs.txt(20248bece2b6ef3394c6eda8541bc0078a870f40 [2016-06-06 15:48:41])]
# my params: {u'N': 30, u'steps': 10, u'sumatra_label': u'534fc0751b1f'}
#
# steps 0
# res 0.00642931458806
# sweeps 0
# dt 0.01
#
# steps 0
# res 1.72825654227e-06
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.00188183642282
# sweeps 0
# dt 0.011
#
# steps 1
# res 3.34202721889e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000601090648088
# sweeps 0
# dt 0.0121
#
# steps 2
# res 8.3094422809e-08
# sweeps 1
# dt 0.0121
#
# steps 3
# res 0.000212074945178
# sweeps 0
# dt 0.01331
#
# steps 3
# res 2.49970028149e-08
# sweeps 1
# dt 0.01331
#
# steps 4
# res 8.23737514717e-05
# sweeps 0
# dt 0.014641
#
# steps 4
# res 8.39907703321e-09
# sweeps 1
# dt 0.014641
#
# steps 5
# res 3.42465036768e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 3.13969115264e-09
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 1.51008898318e-05
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 1.31044046312e-09
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 7.16769769873e-06
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 6.0186090131e-10
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 3.71679012238e-06
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 2.99029929718e-10
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 2.09851157493e-06
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 1.58615127917e-10
# sweeps 1
# dt 0.02357947691
# Record label for this run: '534fc0751b1f'
# Data keys are [c_var_outputs.txt(df1883e683bf570d0219f1e662b9077fbeb226a3 [2016-06-06 15:49:13])]
# my params: {u'N': 30, u'steps': 20, u'sumatra_label': u'22991c08b06b'}
#
# steps 0
# res 0.00642931458806
# sweeps 0
# dt 0.01
#
# steps 0
# res 1.72825654227e-06
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.00188183642282
# sweeps 0
# dt 0.011
#
# steps 1
# res 3.34202721889e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000601090648088
# sweeps 0
# dt 0.0121
#
# steps 2
# res 8.3094422809e-08
# sweeps 1
# dt 0.0121
#
# steps 3
# res 0.000212074945178
# sweeps 0
# dt 0.01331
#
# steps 3
# res 2.49970028149e-08
# sweeps 1
# dt 0.01331
#
# steps 4
# res 8.23737514717e-05
# sweeps 0
# dt 0.014641
#
# steps 4
# res 8.39907703321e-09
# sweeps 1
# dt 0.014641
#
# steps 5
# res 3.42465036768e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 3.13969115264e-09
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 1.51008898318e-05
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 1.31044046312e-09
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 7.16769769873e-06
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 6.0186090131e-10
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 3.71679012238e-06
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 2.99029929718e-10
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 2.09851157493e-06
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 1.58615127917e-10
# sweeps 1
# dt 0.02357947691
#
# steps 10
# res 1.26933291376e-06
# sweeps 0
# dt 0.025937424601
#
# steps 10
# res 8.91351455134e-11
# sweeps 1
# dt 0.025937424601
#
# steps 11
# res 8.09306949148e-07
# sweeps 0
# dt 0.0285311670611
#
# steps 11
# res 5.27326332187e-11
# sweeps 1
# dt 0.0285311670611
#
# steps 12
# res 5.37418195834e-07
# sweeps 0
# dt 0.0313842837672
#
# steps 12
# res 3.25877922345e-11
# sweeps 1
# dt 0.0313842837672
#
# steps 13
# res 3.68359824775e-07
# sweeps 0
# dt 0.0345227121439
#
# steps 13
# res 2.09366523858e-11
# sweeps 1
# dt 0.0345227121439
#
# steps 14
# res 2.58783365209e-07
# sweeps 0
# dt 0.0379749833583
#
# steps 14
# res 1.38545930428e-11
# sweeps 1
# dt 0.0379749833583
#
# steps 15
# res 1.85362005847e-07
# sweeps 0
# dt 0.0417724816942
#
# steps 15
# res 9.46060308389e-12
# sweeps 1
# dt 0.0417724816942
#
# steps 16
# res 1.34892064079e-07
# sweeps 0
# dt 0.0459497298636
#
# steps 16
# res 6.6623917845e-12
# sweeps 1
# dt 0.0459497298636
#
# steps 17
# res 9.95344317785e-08
# sweeps 0
# dt 0.0505447028499
#
# steps 17
# res 4.76973612188e-12
# sweeps 1
# dt 0.0505447028499
#
# steps 18
# res 7.44393972336e-08
# sweeps 0
# dt 0.0555991731349
#
# steps 18
# res 3.5639636867e-12
# sweeps 1
# dt 0.0555991731349
#
# steps 19
# res 5.65028827892e-08
# sweeps 0
# dt 0.0611590904484
#
# steps 19
# res 2.68018044276e-12
# sweeps 1
# dt 0.0611590904484
# Record label for this run: '22991c08b06b'
# Data keys are [c_var_outputs.txt(919a72899236be84b7807a5174c4134b386a7ec7 [2016-06-06 15:49:52])]
# my params: {u'N': 40, u'steps': 2, u'sumatra_label': u'15a42701deca'}
#
# steps 0
# res 0.00853489695285
# sweeps 0
# dt 0.01
#
# steps 0
# res 2.16251847341e-06
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.00235470619447
# sweeps 0
# dt 0.011
#
# steps 1
# res 3.73714827685e-07
# sweeps 1
# dt 0.011
# Record label for this run: '15a42701deca'
# Data keys are [c_var_outputs.txt(ab982e24b195207465b2ee31a854d6b082652f8e [2016-06-06 15:50:26])]
# my params: {u'N': 40, u'steps': 10, u'sumatra_label': u'8df059ad7d76'}
#
# steps 0
# res 0.00853489695285
# sweeps 0
# dt 0.01
#
# steps 0
# res 2.16251847341e-06
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.00235470619447
# sweeps 0
# dt 0.011
#
# steps 1
# res 3.73714827685e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000681598108133
# sweeps 0
# dt 0.0121
#
# steps 2
# res 1.01161059021e-07
# sweeps 1
# dt 0.0121
#
# steps 3
# res 0.00024408148551
# sweeps 0
# dt 0.01331
#
# steps 3
# res 4.49503837221e-08
# sweeps 1
# dt 0.01331
#
# steps 4
# res 0.000114782153804
# sweeps 0
# dt 0.014641
#
# steps 4
# res 2.45410080211e-08
# sweeps 1
# dt 0.014641
#
# steps 5
# res 6.33550008434e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 1.55108638373e-08
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 3.85374456653e-05
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 1.05600788965e-08
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 2.51937418176e-05
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 7.37451415131e-09
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 1.73307593561e-05
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 5.20993662355e-09
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 1.23509042411e-05
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 3.71955443837e-09
# sweeps 1
# dt 0.02357947691
# Record label for this run: '8df059ad7d76'
# Data keys are [c_var_outputs.txt(ec990f64963ace35f3274a31713f6f9850113e96 [2016-06-06 15:51:12])]
# my params: {u'N': 40, u'steps': 20, u'sumatra_label': u'a363c8943090'}
#
# steps 0
# res 0.00853489695285
# sweeps 0
# dt 0.01
#
# steps 0
# res 2.16251847341e-06
# sweeps 1
# dt 0.01
#
# steps 1
# res 0.00235470619447
# sweeps 0
# dt 0.011
#
# steps 1
# res 3.73714827685e-07
# sweeps 1
# dt 0.011
#
# steps 2
# res 0.000681598108133
# sweeps 0
# dt 0.0121
#
# steps 2
# res 1.01161059021e-07
# sweeps 1
# dt 0.0121
#
# steps 3
# res 0.00024408148551
# sweeps 0
# dt 0.01331
#
# steps 3
# res 4.49503837221e-08
# sweeps 1
# dt 0.01331
#
# steps 4
# res 0.000114782153804
# sweeps 0
# dt 0.014641
#
# steps 4
# res 2.45410080211e-08
# sweeps 1
# dt 0.014641
#
# steps 5
# res 6.33550008434e-05
# sweeps 0
# dt 0.0161051
#
# steps 5
# res 1.55108638373e-08
# sweeps 1
# dt 0.0161051
#
# steps 6
# res 3.85374456653e-05
# sweeps 0
# dt 0.01771561
#
# steps 6
# res 1.05600788965e-08
# sweeps 1
# dt 0.01771561
#
# steps 7
# res 2.51937418176e-05
# sweeps 0
# dt 0.019487171
#
# steps 7
# res 7.37451415131e-09
# sweeps 1
# dt 0.019487171
#
# steps 8
# res 1.73307593561e-05
# sweeps 0
# dt 0.0214358881
#
# steps 8
# res 5.20993662355e-09
# sweeps 1
# dt 0.0214358881
#
# steps 9
# res 1.23509042411e-05
# sweeps 0
# dt 0.02357947691
#
# steps 9
# res 3.71955443837e-09
# sweeps 1
# dt 0.02357947691
#
# steps 10
# res 9.03558891271e-06
# sweeps 0
# dt 0.025937424601
#
# steps 10
# res 2.68687623783e-09
# sweeps 1
# dt 0.025937424601
#
# steps 11
# res 6.74865123419e-06
# sweeps 0
# dt 0.0285311670611
#
# steps 11
# res 1.96571618924e-09
# sweeps 1
# dt 0.0285311670611
#
# steps 12
# res 5.12613510836e-06
# sweeps 0
# dt 0.0313842837672
#
# steps 12
# res 1.4576371621e-09
# sweeps 1
# dt 0.0313842837672
#
# steps 13
# res 3.9474002433e-06
# sweeps 0
# dt 0.0345227121439
#
# steps 13
# res 1.0959284317e-09
# sweeps 1
# dt 0.0345227121439
#
# steps 14
# res 3.07395490345e-06
# sweeps 0
# dt 0.0379749833583
#
# steps 14
# res 8.35957802096e-10
# sweeps 1
# dt 0.0379749833583
#
# steps 15
# res 2.41654698133e-06
# sweeps 0
# dt 0.0417724816942
#
# steps 15
# res 6.4733454792e-10
# sweeps 1
# dt 0.0417724816942
#
# steps 16
# res 1.91609341024e-06
# sweeps 0
# dt 0.0459497298636
#
# steps 16
# res 5.09380516159e-10
# sweeps 1
# dt 0.0459497298636
#
# steps 17
# res 1.53228720859e-06
# sweeps 0
# dt 0.0505447028499
#
# steps 17
# res 4.07972308742e-10
# sweeps 1
# dt 0.0505447028499
#
# steps 18
# res 1.23674357508e-06
# sweeps 0
# dt 0.0555991731349
#
# steps 18
# res 3.33057415756e-10
# sweeps 1
# dt 0.0555991731349
#
# steps 19
# res 1.00889912654e-06
# sweeps 0
# dt 0.0611590904484
#
# steps 19
# res 2.7814740116e-10
# sweeps 1
# dt 0.0611590904484
# Record label for this run: 'a363c8943090'
# Data keys are [c_var_outputs.txt(51a082942f97aea1baf860fd23558b4da31ecfbe [2016-06-06 15:51:47])]

# %% [markdown]
# # Import into Pandas Dataframe
#
# The important part of this story is how to import the data into the Pandas data frame. This is actually trivial as Sumatra's default export format is a JSON file with all the records.

# %%
# del(df)
print df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-363ab86352d4> in <module>()
#       1 # del(df)
# ----> 2 print df
#
# NameError: name 'df' is not defined

# %%
import json
import pandas

# !smt export
with open('.smt/records_export.json') as ff:
    data = json.load(ff)
    
with open('record1.json', 'w') as record1:
    for entry in range(len(data)):
        record1.write(json.dumps(data[entry], sort_keys=True, indent=4, separators=(',', ': ')))

df = pandas.DataFrame(data)

# %% [markdown]
# The Sumatra data is now in a Pandas data frame, albeit a touch raw.

# %%
print df['parameters']
# Out:
# 0     {u'content': u'{
#     "N": 40,
#     "steps": 20...
# 1     {u'content': u'{
#     "N": 40,
#     "steps": 10...
# 2     {u'content': u'{
#     "N": 40,
#     "steps": 2,...
# 3     {u'content': u'{
#     "N": 30,
#     "steps": 20...
# 4     {u'content': u'{
#     "N": 30,
#     "steps": 10...
# 5     {u'content': u'{
#     "N": 30,
#     "steps": 2,...
# 6     {u'content': u'{
#     "N": 20,
#     "steps": 20...
# 7     {u'content': u'{
#     "N": 20,
#     "steps": 10...
# 8     {u'content': u'{
#     "N": 20,
#     "steps": 2,...
# 9     {u'content': u'{
#     "N": 15,
#     "steps": 20...
# 10    {u'content': u'{
#     "N": 15,
#     "steps": 10...
# 11    {u'content': u'{
#     "N": 15,
#     "steps": 2,...
# 12    {u'content': u'{
#     "N": 10,
#     "steps": 20...
# 13    {u'content': u'{
#     "N": 10,
#     "steps": 10...
# 14    {u'content': u'{
#     "N": 10,
#     "steps": 2,...
# Name: parameters, dtype: object

# %%
print df[['label', 'duration']]
# Out:
#            label  duration
# 0   a363c8943090  6.824560
# 1   8df059ad7d76  4.038260
# 2   15a42701deca  1.690229
# 3   22991c08b06b  6.143306
# 4   534fc0751b1f  4.022114
# 5   ef3a66163116  1.449261
# 6   779d02f0c3e8  4.782407
# 7   e8ad6a451d27  2.897822
# 8   98812abd136d  1.432834
# 9   e6a47fb8223f  5.025449
# 10  c9ec3e4caf03  2.970374
# 11  36a112015922  1.384827
# 12  d8378b287345  4.363858
# 13  052b46043c22  2.397974
# 14  f26f36cf9d43  3.808108

# %% [markdown]
# # Reformat the Raw Imported Dataframe
#
# While all the meta data is important, often we want the input and
# output data combined into a data frame in a digestible
# form. Typically, we want a graph of reduced input versus reduced
# output.
#
# The first step is to introduce columns in the data frame for each of the input parameters (input data). The input data is buried in the `launch_mode` and `parameters` columns of the raw data frame.

# %%
for index in range(len(df['launch_mode'])):
   print df['launch_mode'][index]['type']
#    print df['launch_mode'][index]['parameters']
# Out:
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode
# SerialLaunchMode

# %%
#not running this cell anymore, it is the original
import json
df = df.copy()
print df.parameters
df['nproc'] = 1 # We are running in serial
for p in 'N', 'steps':
    df[p] = df.parameters.map(lambda x: json.loads(x['content'])[p])

# print df.parameters[0]
# Out:
# 0     {u'content': u'{
#     "N": 40,
#     "steps": 20...
# 1     {u'content': u'{
#     "N": 40,
#     "steps": 10...
# 2     {u'content': u'{
#     "N": 40,
#     "steps": 2,...
# 3     {u'content': u'{
#     "N": 30,
#     "steps": 20...
# 4     {u'content': u'{
#     "N": 30,
#     "steps": 10...
# 5     {u'content': u'{
#     "N": 30,
#     "steps": 2,...
# 6     {u'content': u'{
#     "N": 20,
#     "steps": 20...
# 7     {u'content': u'{
#     "N": 20,
#     "steps": 10...
# 8     {u'content': u'{
#     "N": 20,
#     "steps": 2,...
# 9     {u'content': u'{
#     "N": 15,
#     "steps": 20...
# 10    {u'content': u'{
#     "N": 15,
#     "steps": 10...
# 11    {u'content': u'{
#     "N": 15,
#     "steps": 2,...
# 12    {u'content': u'{
#     "N": 10,
#     "steps": 20...
# 13    {u'content': u'{
#     "N": 10,
#     "steps": 10...
# 14    {u'content': u'{
#     "N": 10,
#     "steps": 2,...
# Name: parameters, dtype: object

# %% [markdown]
# We now have the input data exposed as columns in the data frame.

# %%
columns = ['label', 'nproc', 'N', 'steps', 'tags', 'duration']
print df[columns]
# Out:
#            label  nproc   N  steps     tags
# 0   a363c8943090      1  40     20  [hack1]
# 1   8df059ad7d76      1  40     10  [hack1]
# 2   15a42701deca      1  40      2  [hack1]
# 3   22991c08b06b      1  30     20  [hack1]
# 4   534fc0751b1f      1  30     10  [hack1]
# 5   ef3a66163116      1  30      2  [hack1]
# 6   779d02f0c3e8      1  20     20  [hack1]
# 7   e8ad6a451d27      1  20     10  [hack1]
# 8   98812abd136d      1  20      2  [hack1]
# 9   e6a47fb8223f      1  15     20  [hack1]
# 10  c9ec3e4caf03      1  15     10  [hack1]
# 11  36a112015922      1  15      2  [hack1]
# 12  d8378b287345      1  10     20  [hack1]
# 13  052b46043c22      1  10     10  [hack1]
# 14  f26f36cf9d43      1  10      2  [hack1]

# %% [markdown]
# The following pulls out the run times stored in the output files from each simulation into a `run_time` column.

# %%
df['output_data']
# Out:
# 0     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 1     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 2     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 3     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 4     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 5     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 6     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 7     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 8     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 9     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 10    [{u'path': u'c_var_outputs.txt', u'creation': ...
# 11    [{u'path': u'c_var_outputs.txt', u'creation': ...
# 12    [{u'path': u'c_var_outputs.txt', u'creation': ...
# 13    [{u'path': u'c_var_outputs.txt', u'creation': ...
# 14    [{u'path': u'c_var_outputs.txt', u'creation': ...
# Name: output_data, dtype: object

# %%
df['output_data']
# Out:
# 0     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 1     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 2     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 3     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 4     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 5     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 6     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 7     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 8     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 9     [{u'path': u'c_var_outputs.txt', u'creation': ...
# 10    [{u'path': u'c_var_outputs.txt', u'creation': ...
# 11    [{u'path': u'c_var_outputs.txt', u'creation': ...
# 12    [{u'path': u'c_var_outputs.txt', u'creation': ...
# 13    [{u'path': u'c_var_outputs.txt', u'creation': ...
# 14    [{u'path': u'c_var_outputs.txt', u'creation': ...
# Name: output_data, dtype: object

# %%
import os

datafiles = df['output_data'].map(lambda x: x[0]['path']) 
datapaths = df['datastore'].map(lambda x: x['parameters']['root'])
data = [np.loadtxt(os.path.join(x, y)) for x, y in zip(datapaths, datafiles)]
# print data
#df['run_time'] = [min(d) for d in data]
# print df['output_data'][0]
# Out:
# [array([ 0.44855982,  0.44807944,  0.44690141,  0.44624037,  0.44695085,
#         0.44899289,  0.45150789,  0.45331846,  0.45355423,  0.45209884,
#         0.44965009,  0.44736522,  0.44625518,  0.44661388,  0.44779211,
#         0.44810586,  0.44717231,  0.44667476,  0.44734631,  0.44916021,
#         0.45137256,  0.4529539 ,  0.45314228,  0.45183907,  0.44966036,
#         0.44762139,  0.44660272,  0.44685591,  0.44782239,  0.44846676,
#         0.44883189,  0.44800638,  0.44837558,  0.44984371,  0.45162036,
#         0.45274814,  0.45261418,  0.45124694,  0.44928851,  0.44766653,
#         0.4471208 ,  0.44780413,  0.44915493,  0.45015803,  0.44999307,
#         0.45030134,  0.45009229,  0.45097479,  0.45218992,  0.45278451,
#         0.45222592,  0.45065783,  0.44878395,  0.44748834,  0.44738498,
#         0.44850562,  0.45026832,  0.45175062,  0.45217411,  0.45142096,
#         0.45155668,  0.45206916,  0.45279563,  0.45289529,  0.45194112,
#         0.45017803,  0.44835777,  0.44732049,  0.44755575,  0.44895371,
#         0.45086064,  0.45241325,  0.45299692,  0.45259966,  0.45184121,
#         0.45174782,  0.45259965,  0.45263539,  0.45154332,  0.44972846,
#         0.4480294 ,  0.44725831,  0.44778775,  0.44936767,  0.45125188,
#         0.45257707,  0.45282072,  0.45211308,  0.45120565,  0.45099819,
#         0.45073881,  0.45132047,  0.45063094,  0.44911205,  0.44771497,
#         0.4472774 ,  0.44809706,  0.44981605,  0.4516218 ,  0.45265992,
#         0.45246987,  0.45124099,  0.44975473,  0.44899004,  0.44948613,
#         0.44922613,  0.44912517,  0.44819379,  0.44731552,  0.44731679,
#         0.44844464,  0.45027345,  0.45196736,  0.45272466,  0.45218675,
#         0.45062135,  0.44879426,  0.44758381,  0.44750442,  0.4483549 ,
#         0.44826271,  0.44755124,  0.44703495,  0.44741585,  0.44881353,
#         0.45070997,  0.45225536,  0.45272588,  0.4518987 ,  0.45016559,
#         0.44833244,  0.44719869,  0.44711904,  0.44778126,  0.44838659,
#         0.44852383,  0.44770709,  0.44797235,  0.44934521,  0.45115373,
#         0.4524788 ,  0.45264604,  0.45155676,  0.44972626,  0.44802004,
#         0.4472122 ,  0.44757151,  0.4486793 ,  0.44961708,  0.4495522 ,
#         0.44983723,  0.44950107,  0.45036255,  0.45175281,  0.45268582,
#         0.45249474,  0.45116063,  0.44928052,  0.4477416 ,  0.44726874,
#         0.44805618,  0.44965247,  0.45116286,  0.4517147 ,  0.45103249,
#         0.45130727,  0.45171122,  0.4525518 ,  0.45294342,  0.45230306,
#         0.45070775,  0.44881643,  0.4474953 ,  0.44736328,  0.44847767,
#         0.45030534,  0.45199363,  0.45281739,  0.45258698,  0.45178986,
#         0.45194162,  0.45284212,  0.45302865,  0.45204956,  0.45019598,
#         0.44828519,  0.44720573,  0.44746187,  0.44892339,  0.45089212,
#         0.45245727,  0.45297872,  0.45246073,  0.45158696,  0.45128686,
#         0.45133136,  0.45215701,  0.45146113,  0.44961186,  0.44769255,
#         0.44677996,  0.44738722,  0.44924484,  0.45146239,  0.45298203,
#         0.45311941,  0.4519417 ,  0.45028492,  0.44933327,  0.44983999,
#         0.44989898,  0.4501407 ,  0.44887867,  0.44717556,  0.44634358,
#         0.4470941 ,  0.44920592,  0.45170623,  0.45339804,  0.45347242,
#         0.451924  ,  0.44957481,  0.44767889,  0.44724966,  0.4483724 ]), array([ 0.44749466,  0.44490926,  0.44400517,  0.44539452,  0.4487011 ,
#         0.4525609 ,  0.45528239,  0.45573799,  0.45391981,  0.45078121,
#         0.44603723,  0.44463915,  0.44497377,  0.44714869,  0.45043419,
#         0.45346236,  0.45489988,  0.45415617,  0.45167367,  0.44859525,
#         0.44527607,  0.44554204,  0.44720402,  0.44977057,  0.45227719,
#         0.45366518,  0.45331448,  0.45138208,  0.44872246,  0.44642565,
#         0.44633126,  0.4479657 ,  0.45018683,  0.45215514,  0.45305881,
#         0.45250083,  0.45071073,  0.44844105,  0.44659722,  0.44582585,
#         0.44922768,  0.45113366,  0.45261443,  0.45300094,  0.45206318,
#         0.45017677,  0.44815087,  0.44682447,  0.44666152,  0.44759471,
#         0.45248315,  0.45337617,  0.45316153,  0.45179268,  0.44975266,
#         0.44788689,  0.44699442,  0.44743095,  0.44894797,  0.45086577,
#         0.45418285,  0.45336596,  0.45148995,  0.44921823,  0.4474583 ,
#         0.4469484 ,  0.44789678,  0.4498896 ,  0.45210863,  0.45371772,
#         0.4534927 ,  0.45117459,  0.44853051,  0.44664649,  0.44635619,
#         0.44779173,  0.45031585,  0.45286433,  0.45447979,  0.45468888,
#         0.45125353,  0.44819453,  0.44577707,  0.44511612,  0.44662028,
#         0.44967688,  0.45294488,  0.45506057,  0.45531376,  0.45384413,
#         0.44903936,  0.44595376,  0.44422931,  0.44477842,  0.44755837,
#         0.45142617,  0.45468872,  0.45599248,  0.45499064,  0.4523363 ]), array([ 0.44749466,  0.44490926,  0.44400517,  0.44539452,  0.4487011 ,
#         0.4525609 ,  0.45528239,  0.45573799,  0.45391981,  0.45078121,
#         0.44603723,  0.44463915,  0.44497377,  0.44714869,  0.45043419,
#         0.45346236,  0.45489988,  0.45415617,  0.45167367,  0.44859525,
#         0.44527607,  0.44554204,  0.44720402,  0.44977057,  0.45227719,
#         0.45366518,  0.45331448,  0.45138208,  0.44872246,  0.44642565,
#         0.44633126,  0.4479657 ,  0.45018683,  0.45215514,  0.45305881,
#         0.45250083,  0.45071073,  0.44844105,  0.44659722,  0.44582585,
#         0.44922768,  0.45113366,  0.45261443,  0.45300094,  0.45206318,
#         0.45017677,  0.44815087,  0.44682447,  0.44666152,  0.44759471,
#         0.45248315,  0.45337617,  0.45316153,  0.45179268,  0.44975266,
#         0.44788689,  0.44699442,  0.44743095,  0.44894797,  0.45086577,
#         0.45418285,  0.45336596,  0.45148995,  0.44921823,  0.4474583 ,
#         0.4469484 ,  0.44789678,  0.4498896 ,  0.45210863,  0.45371772,
#         0.4534927 ,  0.45117459,  0.44853051,  0.44664649,  0.44635619,
#         0.44779173,  0.45031585,  0.45286433,  0.45447979,  0.45468888,
#         0.45125353,  0.44819453,  0.44577707,  0.44511612,  0.44662028,
#         0.44967688,  0.45294488,  0.45506057,  0.45531376,  0.45384413,
#         0.44903936,  0.44595376,  0.44422931,  0.44477842,  0.44755837,
#         0.45142617,  0.45468872,  0.45599248,  0.45499064,  0.4523363 ]), array([ 0.44749466,  0.44490926,  0.44400517,  0.44539452,  0.4487011 ,
#         0.4525609 ,  0.45528239,  0.45573799,  0.45391981,  0.45078121,
#         0.44603723,  0.44463915,  0.44497377,  0.44714869,  0.45043419,
#         0.45346236,  0.45489988,  0.45415617,  0.45167367,  0.44859525,
#         0.44527607,  0.44554204,  0.44720402,  0.44977057,  0.45227719,
#         0.45366518,  0.45331448,  0.45138208,  0.44872246,  0.44642565,
#         0.44633126,  0.4479657 ,  0.45018683,  0.45215514,  0.45305881,
#         0.45250083,  0.45071073,  0.44844105,  0.44659722,  0.44582585,
#         0.44922768,  0.45113366,  0.45261443,  0.45300094,  0.45206318,
#         0.45017677,  0.44815087,  0.44682447,  0.44666152,  0.44759471,
#         0.45248315,  0.45337617,  0.45316153,  0.45179268,  0.44975266,
#         0.44788689,  0.44699442,  0.44743095,  0.44894797,  0.45086577,
#         0.45418285,  0.45336596,  0.45148995,  0.44921823,  0.4474583 ,
#         0.4469484 ,  0.44789678,  0.4498896 ,  0.45210863,  0.45371772,
#         0.4534927 ,  0.45117459,  0.44853051,  0.44664649,  0.44635619,
#         0.44779173,  0.45031585,  0.45286433,  0.45447979,  0.45468888,
#         0.45125353,  0.44819453,  0.44577707,  0.44511612,  0.44662028,
#         0.44967688,  0.45294488,  0.45506057,  0.45531376,  0.45384413,
#         0.44903936,  0.44595376,  0.44422931,  0.44477842,  0.44755837,
#         0.45142617,  0.45468872,  0.45599248,  0.45499064,  0.4523363 ])]

# %% [markdown]
# Create masks based on simulations records that have been tagged with either `demo2` or `demo3`. We want to plot these results as different curves on the same graph.

# %%
tag_mask = df.tags.map(lambda x: 'hack1' in x)
df_tmp = df[tag_mask]
# print df_tmp
m10 = df_tmp.N.map(lambda x: x == 10)
m15 = df_tmp.N.map(lambda x: x == 15)
m20 = df_tmp.N.map(lambda x: x == 20)
m30 = df_tmp.N.map(lambda x: x == 30)
m40 = df_tmp.N.map(lambda x: x == 40)
df_N10 = df_tmp[m10]
df_N15 = df_tmp[m15]
df_N20 = df_tmp[m20]
df_N30 = df_tmp[m30]
df_N40 = df_tmp[m40]
print df_N10[columns]
print df_N15[columns]
print df_N20[columns]
print df_N30[columns]
print df_N40[columns]

# print df_tmp
# Out:
#            label  nproc   N  steps     tags
# 12  d8378b287345      1  10     20  [hack1]
# 13  052b46043c22      1  10     10  [hack1]
# 14  f26f36cf9d43      1  10      2  [hack1]
#            label  nproc   N  steps     tags
# 9   e6a47fb8223f      1  15     20  [hack1]
# 10  c9ec3e4caf03      1  15     10  [hack1]
# 11  36a112015922      1  15      2  [hack1]
#           label  nproc   N  steps     tags
# 6  779d02f0c3e8      1  20     20  [hack1]
# 7  e8ad6a451d27      1  20     10  [hack1]
# 8  98812abd136d      1  20      2  [hack1]
#           label  nproc   N  steps     tags
# 3  22991c08b06b      1  30     20  [hack1]
# 4  534fc0751b1f      1  30     10  [hack1]
# 5  ef3a66163116      1  30      2  [hack1]
#           label  nproc   N  steps     tags
# 0  a363c8943090      1  40     20  [hack1]
# 1  8df059ad7d76      1  40     10  [hack1]
# 2  15a42701deca      1  40      2  [hack1]

# %% [markdown]
# We can plot the results we're interested in. Larger system size gives better parallel speed up.

# %%
df_N40['steps']
# Out:
# 0    20
# 1    10
# 2     2
# Name: steps, dtype: int64

# %%
ax = df_N10.plot('N', 'duration', kind='scatter', s=10, label='N={0}'.format(df_N10.N.iat[0]))
df_N15.plot('N', 'duration', kind='scatter', s=10, ylim=0, ax=ax, label='N={0}'.format(df_N15.N.iat[0]))
df_N20.plot('N', 'duration', kind='scatter', s=10, ylim=0, ax=ax, label='N={0}'.format(df_N20.N.iat[0]))
df_N30.plot('N', 'duration', kind='scatter', s=10, ylim=0, ax=ax, label='N={0}'.format(df_N30.N.iat[0]))
df_N40.plot('N', 'duration', kind='scatter', s=10, ylim=0, ax=ax, label='N={0}'.format(df_N40.N.iat[0]))
ax.set_xlim([5,55])
ax.set_ylim([.2,10])
plt.ylabel('Run Time (s)')
plt.xlabel('Grid sizes')
plt.legend()

# %% [markdown]
# Using Pandas it is easy to store a custom data frame.

# %%
df.to_hdf('store.h5', 'df')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-115-75319471dfb0> in <module>()
# ----> 1 df.to_hdf('store.h5', 'df')
#
# /users/aem1/miniconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in to_hdf(self, path_or_buf, key, **kwargs)
#    1099
#    1100         from pandas.io import pytables
# -> 1101         return pytables.to_hdf(path_or_buf, key, self, **kwargs)
#    1102
#    1103     def to_msgpack(self, path_or_buf=None, encoding='utf-8', **kwargs):
#
# /users/aem1/miniconda2/lib/python2.7/site-packages/pandas/io/pytables.pyc in to_hdf(path_or_buf, key, value, mode, complevel, complib, append, **kwargs)
#     257     if isinstance(path_or_buf, string_types):
#     258         with HDFStore(path_or_buf, mode=mode, complevel=complevel,
# --> 259                       complib=complib) as store:
#     260             f(store)
#     261     else:
#
# /users/aem1/miniconda2/lib/python2.7/site-packages/pandas/io/pytables.pyc in __init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     387         except ImportError as ex:  # pragma: no cover
#     388             raise ImportError('HDFStore requires PyTables, "{ex}" problem '
# --> 389                               'importing'.format(ex=str(ex)))
#     390
#     391         if complib not in (None, 'blosc', 'bzip2', 'lzo', 'zlib'):
#
# ImportError: HDFStore requires PyTables, "No module named tables" problem importing

# %%
b
print store.df.dependencies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-116-4dbaddea8b62> in <module>()
# ----> 1 b
#       2 print store.df.dependencies
#
# NameError: name 'b' is not defined

# %%
import pandas as pd

df = pd.DataFrame({'a' : [1, 2, 3], 'b' : ['a', 'b', 'c']})
df['c'] = [5, 6, 7]
print df
# Out:
#    a  b  c
# 0  1  a  5
# 1  2  b  6
# 2  3  c  7

# %% [markdown]
# # Conclusion
#
# Sumatra stores data in an SQL style database and this isn't ideal for pulling data into Python for data manipulation. Pandas is good for data manipulation and pulling the records out of Sumatra and into Pandas is very easy.
